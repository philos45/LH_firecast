# %%
import pandas as pd
import numpy as np
train = pd.read_csv("../원본_data/PJT002_train.csv",encoding="utf-8")
test = pd.read_csv("../원본_data/PJT002_test.csv",encoding="utf-8")
val = pd.read_csv("../원본_data/PJT002_validation.csv",encoding="utf-8")
del train["id"]
del test["id"]
del val["id"]
col_list = ["화재발생일시","화재발생여부","건물용도","건물구조","건물채수","건물건축면적","건물연면적(건물층별합계전체 면적)","토지면적","건물승인일자","건물들의 지상 층수의 합","건물들의 지하 층수의 합","건물용도분류명","온도(c)","강수량","풍속","풍향","습도","가스에너지사용량201401","전기에너지사용량201401","가스에너지사용량201402","전기에너지사용량201402","가스에너지사용량201403","전기에너지사용량201403","가스에너지사용량201404","전기에너지사용량201404","가스에너지사용량201405","전기에너지사용량201405","가스에너지사용량201406","전기에너지사용량201406","가스에너지사용량201407","전기에너지사용량201407","가스에너지사용량201408","전기에너지사용량201408","가스에너지사용량201409","전기에너지사용량201409","가스에너지사용량201410","전기에너지사용량201410","가스에너지사용량201411","전기에너지사용량201411","가스에너지사용량201412","전기에너지사용량201412","가스에너지사용량201501","전기에너지사용량201501","가스에너지사용량201502","전기에너지사용량201502","가스에너지사용량201503","전기에너지사용량201503","가스에너지사용량201504","전기에너지사용량201504","가스에너지사용량201505","전기에너지사용량201505","가스에너지사용량201506","전기에너지사용량201506","가스에너지사용량201507","전기에너지사용량201507","가스에너지사용량201508","전기에너지사용량201508","가스에너지사용량201509","전기에너지사용량201509","가스에너지사용량201510","전기에너지사용량201510","가스에너지사용량201511","전기에너지사용량201511","가스에너지사용량201512","전기에너지사용량201512","가스에너지사용량201601","전기에너지사용량201601","가스에너지사용량201602","전기에너지사용량201602","가스에너지사용량201603","전기에너지사용량201603","가스에너지사용량201604","전기에너지사용량201604","가스에너지사용량201605","전기에너지사용량201605","가스에너지사용량201606","전기에너지사용량201606","가스에너지사용량201607","전기에너지사용량201607","가스에너지사용량201608","전기에너지사용량201608","가스에너지사용량201609","전기에너지사용량201609","가스에너지사용량201610","전기에너지사용량201610","가스에너지사용량201611","전기에너지사용량201611","가스에너지사용량201612","전기에너지사용량201612","가스에너지사용량201701","전기에너지사용량201701","가스에너지사용량201702","전기에너지사용량201702","가스에너지사용량201703","전기에너지사용량201703","가스에너지사용량201704","전기에너지사용량201704","가스에너지사용량201705","전기에너지사용량201705","가스에너지사용량201706","전기에너지사용량201706","가스에너지사용량201707","전기에너지사용량201707","가스에너지사용량201708","전기에너지사용량201708","가스에너지사용량201709","전기에너지사용량201709","가스에너지사용량201710","전기에너지사용량201710","가스에너지사용량201711","전기에너지사용량201711","가스에너지사용량201712","전기에너지사용량201712","가스에너지사용량201801","전기에너지사용량201801","가스에너지사용량201802","전기에너지사용량201802","가스에너지사용량201803","전기에너지사용량201803","가스에너지사용량201804","전기에너지사용량201804","가스에너지사용량201805","전기에너지사용량201805","가스에너지사용량201806","전기에너지사용량201806","가스에너지사용량201807","전기에너지사용량201807","가스에너지사용량201808","전기에너지사용량201808","가스에너지사용량201809","전기에너지사용량201809","가스에너지사용량201810","전기에너지사용량201810","가스에너지사용량201811","전기에너지사용량201811","가스에너지사용량201812","전기에너지사용량201812","복도,계단,출입구의 성능 유지여부(0~5)","옥상광장의 피난성능 유지여부(0~5)","방화문, 방화셔터 등의 성능 유지여부(0~5)","방화구획 적합 여부(0~5)","경계벽 및 칸막이벽의 변경 등 방화성능 유지여부(0~5)","배연설비의 성능 유지여부(0~5)","내화구조의 성능 유지여부(0~5)","방화벽의 성능 유지여부(0~5)","외벽의 성능 유지여부(0~5)","창호의 성능 유지여부(0~5)","내부마감의 방화성능 유지여부(0~5)","외부마감의 노후화 및 마감재 탈락 여부(0~5)","지하층의 소방설비 성능 유지여부(0~5)","지하층 피난구,피난계단의 성능 유지여부(0~5)","지적상 지목","용도지역지구명","용도지역지구명2","토지이용상황명","도로측면명","행정구역명","행정구역 인구","119 안전센터와의 거리","단위 면적당 건물 가격(2019년)","소방용수시설(소화전 등)과의 최소 거리","관할 소방서 인원","다중이용시설 포함여부","공공 CCTV와의 최소 거리","반경 100m 이내 소방용수 시설 수","반경 100m 이내 공공 CCTV","담배 소매점과의 최소 거리","안전 비상벨과의 최소 거리","자동 심장 충격기와의 최소 거리","금연구역과의 최소 거리","50m내건물수","소방관리대상물기준","소방시설특례5호여부","소방시설특례6호여부","사용여부","위험물대상여부","자체소방대여부","대량위험물제조소등여부","문화재여부"]

total = pd.concat([train,val,test],sort=False)

for i in range(len(col_list)):
    total.rename(columns={total.columns[i]:col_list[i]},inplace=True)
화재발생여부 = []
for i in range(len(total)):
    if total["화재발생여부"].values[i] == "Y":
        화재발생여부.append(1)
    elif total["화재발생여부"].values[i] == "N":
        화재발생여부.append(0)
    else:
        화재발생여부.append(2)
total["화재발생여부"] = 화재발생여부
#total.to_csv("01. total(train+val+test).csv",encoding="euc-kr")

train = pd.read_csv("../원본_data/PJT002_train.csv",encoding="utf-8")
test = pd.read_csv("../원본_data/PJT002_test.csv",encoding="utf-8")
val = pd.read_csv("../원본_data/PJT002_validation.csv",encoding="utf-8")
del train["id"]
del test["id"]
del val["id"]
val_화재여부 = val["fr_yn"]
test_화재여부 = test["fr_yn"]

del val["fr_yn"]
del test["fr_yn"]

k_col_list = ["화재발생일시","건물용도","건물구조","건물채수","건물건축면적","건물연면적(건물층별합계전체 면적)","토지면적","건물승인일자","건물들의 지상 층수의 합","건물들의 지하 층수의 합","건물용도분류명","온도(c)","강수량","풍속","풍향","습도","가스에너지사용량201401","전기에너지사용량201401","가스에너지사용량201402","전기에너지사용량201402","가스에너지사용량201403","전기에너지사용량201403","가스에너지사용량201404","전기에너지사용량201404","가스에너지사용량201405","전기에너지사용량201405","가스에너지사용량201406","전기에너지사용량201406","가스에너지사용량201407","전기에너지사용량201407","가스에너지사용량201408","전기에너지사용량201408","가스에너지사용량201409","전기에너지사용량201409","가스에너지사용량201410","전기에너지사용량201410","가스에너지사용량201411","전기에너지사용량201411","가스에너지사용량201412","전기에너지사용량201412","가스에너지사용량201501","전기에너지사용량201501","가스에너지사용량201502","전기에너지사용량201502","가스에너지사용량201503","전기에너지사용량201503","가스에너지사용량201504","전기에너지사용량201504","가스에너지사용량201505","전기에너지사용량201505","가스에너지사용량201506","전기에너지사용량201506","가스에너지사용량201507","전기에너지사용량201507","가스에너지사용량201508","전기에너지사용량201508","가스에너지사용량201509","전기에너지사용량201509","가스에너지사용량201510","전기에너지사용량201510","가스에너지사용량201511","전기에너지사용량201511","가스에너지사용량201512","전기에너지사용량201512","가스에너지사용량201601","전기에너지사용량201601","가스에너지사용량201602","전기에너지사용량201602","가스에너지사용량201603","전기에너지사용량201603","가스에너지사용량201604","전기에너지사용량201604","가스에너지사용량201605","전기에너지사용량201605","가스에너지사용량201606","전기에너지사용량201606","가스에너지사용량201607","전기에너지사용량201607","가스에너지사용량201608","전기에너지사용량201608","가스에너지사용량201609","전기에너지사용량201609","가스에너지사용량201610","전기에너지사용량201610","가스에너지사용량201611","전기에너지사용량201611","가스에너지사용량201612","전기에너지사용량201612","가스에너지사용량201701","전기에너지사용량201701","가스에너지사용량201702","전기에너지사용량201702","가스에너지사용량201703","전기에너지사용량201703","가스에너지사용량201704","전기에너지사용량201704","가스에너지사용량201705","전기에너지사용량201705","가스에너지사용량201706","전기에너지사용량201706","가스에너지사용량201707","전기에너지사용량201707","가스에너지사용량201708","전기에너지사용량201708","가스에너지사용량201709","전기에너지사용량201709","가스에너지사용량201710","전기에너지사용량201710","가스에너지사용량201711","전기에너지사용량201711","가스에너지사용량201712","전기에너지사용량201712","가스에너지사용량201801","전기에너지사용량201801","가스에너지사용량201802","전기에너지사용량201802","가스에너지사용량201803","전기에너지사용량201803","가스에너지사용량201804","전기에너지사용량201804","가스에너지사용량201805","전기에너지사용량201805","가스에너지사용량201806","전기에너지사용량201806","가스에너지사용량201807","전기에너지사용량201807","가스에너지사용량201808","전기에너지사용량201808","가스에너지사용량201809","전기에너지사용량201809","가스에너지사용량201810","전기에너지사용량201810","가스에너지사용량201811","전기에너지사용량201811","가스에너지사용량201812","전기에너지사용량201812","복도,계단,출입구의 성능 유지여부(0~5)","옥상광장의 피난성능 유지여부(0~5)","방화문, 방화셔터 등의 성능 유지여부(0~5)","방화구획 적합 여부(0~5)","경계벽 및 칸막이벽의 변경 등 방화성능 유지여부(0~5)","배연설비의 성능 유지여부(0~5)","내화구조의 성능 유지여부(0~5)","방화벽의 성능 유지여부(0~5)","외벽의 성능 유지여부(0~5)","창호의 성능 유지여부(0~5)","내부마감의 방화성능 유지여부(0~5)","외부마감의 노후화 및 마감재 탈락 여부(0~5)","지하층의 소방설비 성능 유지여부(0~5)","지하층 피난구,피난계단의 성능 유지여부(0~5)","지적상 지목","용도지역지구명","용도지역지구명2","토지이용상황명","도로측면명","행정구역명","행정구역 인구","119 안전센터와의 거리","단위 면적당 건물 가격(2019년)","소방용수시설(소화전 등)과의 최소 거리","관할 소방서 인원","다중이용시설 포함여부","공공 CCTV와의 최소 거리","반경 100m 이내 소방용수 시설 수","반경 100m 이내 공공 CCTV","담배 소매점과의 최소 거리","안전 비상벨과의 최소 거리","자동 심장 충격기와의 최소 거리","금연구역과의 최소 거리","50m내건물수","소방관리대상물기준","소방시설특례5호여부","소방시설특례6호여부","사용여부","위험물대상여부","자체소방대여부","대량위험물제조소등여부","문화재여부"]
kimhae = pd.concat([val,test],sort=False)
for i in range(len(k_col_list)):
    kimhae.rename(columns={kimhae.columns[i]:k_col_list[i]},inplace=True)
김해화재여부 = pd.concat([val_화재여부,test_화재여부])
김해화재발생여부 = []
for i in range(len(김해화재여부)):
    if 김해화재여부.values[i] == "Y":
        김해화재발생여부.append(1)
    elif 김해화재여부.values[i] == "N":
        김해화재발생여부.append(0)
    else:
        김해화재발생여부.append(2)
kimhae["화재발생여부"] = 김해화재발생여부
#kimhae.to_csv("01. kimhae(val+test).csv",encoding="euc-kr")
김해시간 = kimhae["화재발생일시"]
del kimhae["화재발생일시"]
전체시간 = total["화재발생일시"]
del total["화재발생일시"]
화재여부 = kimhae["화재발생여부"]
del kimhae["화재발생여부"]
total = pd.concat([전체시간,total],axis=1)
kimhae = pd.concat([김해시간,화재여부,kimhae],axis=1)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3058: DtypeWarning: Columns (8,172,173,174,175,176,177,178,179) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
total.to_csv("01. total(train+val+test).csv",encoding="euc-kr")

# %%
kimhae.to_csv("01. kimhae(val+test).csv",encoding="euc-kr")
# Out:
#       화재발생여부     건물용도      건물구조  건물채수   건물건축면적  건물연면적(건물층별합계전체 면적)    토지면적  \
# 0          1     단독주택      블록구조     3    69.42               69.42     0.0
# 1          0      NaN       NaN     3    46.29               46.29     0.0
# 2          1     공동주택  철근콘크리트구조     1   583.80             2516.76  1446.0
# 3          0     단독주택     일반목구조     2    48.92               48.92     0.0
# 4          0      NaN       NaN     2     0.00                0.00     0.0
# ...      ...      ...       ...   ...      ...                 ...     ...
# 2952       2     단독주택  철근콘크리트구조     1   122.45              329.55   288.0
# 2953       2      NaN       NaN     4    52.89               52.89     0.0
# 2954       2     단독주택  철근콘크리트구조     1   166.05              466.82   277.3
# 2955       2  자동차관련시설    경량철골구조     1   250.00              240.00   827.8
# 2956       2     업무시설  철근콘크리트구조     2  2055.80             6169.88  3767.6
#
# ...
